# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sivam\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sivam\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sivam\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
from ultralytics import YOLO

# Load YOLOv8n (nano) - small & fast for real-time use
model = YOLO("yolov8n.pt")

# Train on your dataset
model.train(
    data="D:/dL yolo v8/data.yaml",
    epochs=25,       # you can increase if needed
    imgsz=640,
    batch=8
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.206 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.202  Python-3.11.3 torch-2.7.0+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# ...

# %%
import cv2
from ultralytics import YOLO
import winsound

# Load trained model
model = YOLO("runs/detect/train4/weights/best.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, stream=True)
    alert_triggered = False

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = box.xyxy[0].int().tolist()
            cls = int(box.cls[0])
            conf = float(box.conf[0])
            label = model.names[cls]

            color = (0, 255, 0) if label == "id_card_worn" else (0, 0, 255)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

            if label == "id_card_not_worn" and not alert_triggered:
                winsound.Beep(1000, 300)
                alert_triggered = True

    cv2.imshow("Real-Time ID Card Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 126.1ms
# Speed: 16.5ms preprocess, 126.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.8ms
# Speed: 3.4ms preprocess, 135.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 153.0ms
# Speed: 2.5ms preprocess, 153.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.1ms
# Speed: 1.8ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.4ms
# Speed: 1.8ms preprocess, 97.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.9ms
# Speed: 1.8ms preprocess, 96.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.0ms
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# Load trained YOLOv8 model
model = YOLO("runs/detect/train4/weights/best.pt")

# Path to your test image
image_path = "D:/dL yolo v8/testimg4.jpg"  # replace with your image path


frame = cv2.imread(image_path)
frame = cv2.resize(frame, (1600, 1200))


if frame is None:
    print("Error: Could not read image.")
    exit()

# Run YOLOv8 prediction
results = model.predict(source=frame)

# Draw boxes and labels
for result in results:
    boxes = result.boxes.xyxy
    cls_ids = result.boxes.cls
    confs = result.boxes.conf

    for box, cls, conf in zip(boxes, cls_ids, confs):
        x1, y1, x2, y2 = map(int, box)
        class_name = model.names[int(cls)]
        color = (0, 255, 0) if class_name == "id_card_worn" else (0, 0, 255)

        # Draw rectangle and label
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, f"{class_name} {conf:.2f}", (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        # Alert if ID not worn
        if class_name == "id_card_not_worn":
            cv2.putText(frame, "ALERT: ID NOT WORN!", (50,50),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 3)

# Show the image with detection
cv2.imshow("ID Card Detection", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 idcards, 8 persons, 112.4ms
# Speed: 4.0ms preprocess, 112.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO
import cv2

# Load your trained YOLOv8 model
model = YOLO("runs/detect/train4/weights/best.pt")

# Path to input video
video_path = "D:/dL yolo v8/testvedio.mp4"   # 🔹 Replace with your video path
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get video frame width, height, and FPS to save output
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps    = cap.get(cv2.CAP_PROP_FPS)

# Define codec and create VideoWriter to save output video
out = cv2.VideoWriter(
    "D:/dL yolo v8/output_video.mp4",   # 🔹 Output path
    cv2.VideoWriter_fourcc(*'mp4v'), 
    fps, 
    (width, height)
)

# Process video frame by frame
while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    # Run YOLO prediction on the current frame
    results = model.predict(source=frame, conf=0.5, verbose=False)

    # Draw detections on frame
    for result in results:
        boxes = result.boxes.xyxy
        cls_ids = result.boxes.cls
        confs = result.boxes.conf

        for box, cls, conf in zip(boxes, cls_ids, confs):
            x1, y1, x2, y2 = map(int, box)
            class_name = model.names[int(cls)]
            color = (0, 255, 0) if class_name == "id_card_worn" else (0, 0, 255)

            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{class_name} {conf:.2f}", (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

            # Alert text for missing ID
            if class_name == "id_card_not_worn":
                cv2.putText(frame, "ALERT: ID NOT WORN!", (50,50),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 3)

    # Show the frame
    cv2.imshow("ID Card Detection - Video", frame)

    # Save output frame to file
    out.write(frame)

    # Press 'q' to stop early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
